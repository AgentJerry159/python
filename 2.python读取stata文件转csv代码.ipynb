# %%
import pandas as pd

# 输入文件路径（Stata文件）
file_path = r"E:\文献阅读\科研学习\身心健康\Health_Status_and_Functioning\Health_Status_and_Functioning.dta"

# 输出文件路径（CSV文件）
output_csv_path = r"E:\文献阅读\科研学习\身心健康\Health_Status_and_Functioning\Health_Status_and_Functioning.csv"

# 读取Stata文件
df = pd.read_stata(file_path)

# 将DataFrame写入CSV文件，保存到指定路径
df.to_csv(output_csv_path, 
          index=False,  # 不保存行索引
          encoding='utf-8-sig')  # 使用支持中文的编码

print(f"✅ 转换成功！")
print(f"📁 原文件: {file_path}")
print(f"📁 新文件: {output_csv_path}")
print(f"📊 数据维度: {df.shape[0]} 行 × {df.shape[1]} 列")
# Out:
# ✅ 转换成功！
# 📁 原文件: E:\文献阅读\科研学习\身心健康\Health_Status_and_Functioning\Health_Status_and_Functioning.dta
# 📁 新文件: E:\文献阅读\科研学习\身心健康\Health_Status_and_Functioning\Health_Status_and_Functioning.csv
# 📊 数据维度: 19367 行 × 936 列
